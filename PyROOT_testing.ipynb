# %%
import ROOT
import numpy as np

file = ROOT.TFile("/lustre19/expphy/volatile/halla/sbs/seeds/rootfiles/hcal_gmn_fullreplay_13747_stream0_seg0_0.root")
T = file.Get("T")

c1 = ROOT.TCanvas("c1", "1D", 800, 600)
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %%
T.Draw("sbs.hcal.e")

# %%
c1.Draw()

# %%
c2 = ROOT.TCanvas("c2", "2D", 800, 600)

T.Draw("sbs.hcal.e:sbs.hcal.x")
c2.Draw()

# %%
c3 = ROOT.TCanvas("c3", "3D", 800, 600)

T.Draw("sbs.hcal.e:sbs.hcal.x:sbs.hcal.y", "", "surf")
c3.Draw()

# %%
#c4 = ROOT.TCanvas("c4", "c4", 800, 600)
#T.Draw("sbs.hcal.x:sbs.hcal.y", "", "colz")
#c4.Draw()
